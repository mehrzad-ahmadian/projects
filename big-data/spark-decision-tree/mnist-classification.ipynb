# %%
import time
from pyspark.ml import Pipeline
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Classification").master("local[4]").config("spark.executor.cores", 4).getOrCreate()

# %%
path ="data/"
train_mnist = spark.read.csv(path+'mnist_train.csv',inferSchema=True)
test_mnist = spark.read.csv(path+'mnist_test.csv',inferSchema=True)

# %%
train_mnist.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- _c1: integer (nullable = true)
#  |-- _c2: integer (nullable = true)
#  |-- _c3: integer (nullable = true)
#  |-- _c4: integer (nullable = true)
#  |-- _c5: integer (nullable = true)
#  |-- _c6: integer (nullable = true)
#  |-- _c7: integer (nullable = true)
#  |-- _c8: integer (nullable = true)
#  |-- _c9: integer (nullable = true)
#  |-- _c10: integer (nullable = true)
#  |-- _c11: integer (nullable = true)
#  |-- _c12: integer (nullable = true)
#  |-- _c13: integer (nullable = true)
#  |-- _c14: integer (nullable = true)
#  |-- _c15: integer (nullable = true)
#  |-- _c16: integer (nullable = true)
#  |-- _c17: integer (nullable = true)
#  |-- _c18: integer (nullable = true)
#  |-- _c19: integer (nullable = true)
#  |-- _c20: integer (nullable = true)
#  |-- _c21: integer (nullable = true)
#  |-- _c22: integer (nullable = true)
#  |-- _c23: integer (nullable = true)
#  |-- _c24: integer (nullable = true)
#  |-- _c25: integer (nullable = true)
#  |-- _c26: integer (nullable = true)
#  |-- _c27: integer (nullable = true)
#  |-- _c28: integer (nullable = true)
#  |-- _c29: integer (nullable = true)
#  |-- _c30: integer (nullable = true)
#  |-- _c31: integer (nullable = true)
#  |-- _c32: integer (nullable = true)
#  |-- _c33: integer (nullable = true)
#  |-- _c34: integer (nullable = true)
#  |-- _c35: integer (nullable = true)
#  |-- _c36: integer (nullable = true)
#  |-- _c37: integer (nullable = true)
#  |-- _c38: integer (nullable = true)
#  |-- _c39: integer (nullable = true)
#  |-- _c40: integer (nullable = true)
#  |-- _c41: integer (nullable = true)
#  |-- _c42: integer (nullable = true)
#  |-- _c43: integer (nullable = true)
#  |-- _c44: integer (nullable = true)
#  |-- _c45: integer (nullable = true)
#  |-- _c46: integer (nullable = true)
#  |-- _c47: integer (nullable = true)
#  |-- _c48: integer (nullable = true)
#  |-- _c49: integer (nullable = true)
#  |-- _c50: integer (nullable = true)
#  |-- _c51: integer (nullable = true)
#  |-- _c52: integer (nullable = true)
#  |-- _c53: integer (nullable = true)
#  |-- _c54: integer (nullable = true)
#  |-- _c55: integer (nullable = true)
#  |-- _c56: integer (nullable = true)
#  |-- _c57: integer (nullable = true)
#  |-- _c58: integer (nullable = true)
#  |-- _c59: integer (nullable = true)
#  |-- _c60: integer (nullable = true)
#  |-- _c61: integer (nullable = true)
#  |-- _c62: integer (nullable = true)
#  |-- _c63: integer (nullable = true)
#  |-- _c64: integer (nullable = true)
#  |-- _c65: integer (nullable = true)
#  |-- _c66: integer (nullable = true)
#  |-- _c67: integer (nullable = true)
#  |-- _c68: integer (nullable = true)
#  |-- _c69: integer (nullable = true)
#  |-- _c70: integer (nullable = true)
#  |-- _c71: integer (nullable = true)
#  |-- _c72: integer (nullable = true)
#  |-- _c73: integer (nullable = true)
#  |-- _c74: integer (nullable = true)
#  |-- _c75: integer (nullable = true)
#  |-- _c76: integer (nullable = true)
#  |-- _c77: integer (nullable = true)
#  |-- _c78: integer (nullable = true)
#  |-- _c79: integer (nullable = true)
#  |-- _c80: integer (nullable = true)
#  |-- _c81: integer (nullable = true)
#  |-- _c82: integer (nullable = true)
#  |-- _c83: integer (nullable = true)
#  |-- _c84: integer (nullable = true)
#  |-- _c85: integer (nullable = true)
#  |-- _c86: integer (nullable = true)
#  |-- _c87: integer (nullable = true)
#  |-- _c88: integer (nullable = true)
#  |-- _c89: integer (nullable = true)
#  |-- _c90: integer (nullable = true)
#  |-- _c91: integer (nullable = true)
#  |-- _c92: integer (nullable = true)
#  |-- _c93: integer (nullable = true)
#  |-- _c94: integer (nullable = true)
#  |-- _c95: integer (nullable = true)
#  |-- _c96: integer (nullable = true)
#  |-- _c97: integer (nullable = true)
#  |-- _c98: integer (nullable = true)
#  |-- _c99: integer (nullable = true)
#  |-- _c100: integer (nullable = true)
#  |-- _c101: integer (nullable = true)
#  |-- _c102: integer (nullable = true)
#  |-- _c103: integer (nullable = true)
#  |-- _c104: integer (nullable = true)
#  |-- _c105: integer (nullable = true)
#  |-- _c106: integer (nullable = true)
#  |-- _c107: integer (nullable = true)
#  |-- _c108: integer (nullable = true)
#  |-- _c109: integer (nullable = true)
#  |-- _c110: integer (nullable = true)
#  |-- _c111: integer (nullable = true)
#  |-- _c112: integer (nullable = true)
#  |-- _c113: integer (nullable = true)
#  |-- _c114: integer (nullable = true)
#  |-- _c115: integer (nullable = true)
#  |-- _c116: integer (nullable = true)
#  |-- _c117: integer (nullable = true)
#  |-- _c118: integer (nullable = true)
#  |-- _c119: integer (nullable = true)
#  |-- _c120: integer (nullable = true)
#  |-- _c121: integer (nullable = true)
#  |-- _c122: integer (nullable = true)
#  |-- _c123: integer (nullable = true)
#  |-- _c124: integer (nullable = true)
#  |-- _c125: integer (nullable = true)
#  |-- _c126: integer (nullable = true)
#  |-- _c127: integer (nullable = true)
#  |-- _c128: integer (nullable = true)
#  |-- _c129: integer (nullable = true)
#  |-- _c130: integer (nullable = true)
#  |-- _c131: integer (nullable = true)
#  |-- _c132: integer (nullable = true)
#  |-- _c133: integer (nullable = true)
#  |-- _c134: integer (nullable = true)
#  |-- _c135: integer (nullable = true)
#  |-- _c136: integer (nullable = true)
#  |-- _c137: integer (nullable = true)
#  |-- _c138: integer (nullable = true)
#  |-- _c139: integer (nullable = true)
#  |-- _c140: integer (nullable = true)
#  |-- _c141: integer (nullable = true)
#  |-- _c142: integer (nullable = true)
#  |-- _c143: integer (nullable = true)
#  |-- _c144: integer (nullable = true)
#  |-- _c145: integer (nullable = true)
#  |-- _c146: integer (nullable = true)
#  |-- _c147: integer (nullable = true)
#  |-- _c148: integer (nullable = true)
#  |-- _c149: integer (nullable = true)
#  |-- _c150: integer (nullable = true)
#  |-- _c151: integer (nullable = true)
#  |-- _c152: integer (nullable = true)
#  |-- _c153: integer (nullable = true)
#  |-- _c154: integer (nullable = true)
#  |-- _c155: integer (nullable = true)
#  |-- _c156: integer (nullable = true)
#  |-- _c157: integer (nullable = true)
#  |-- _c158: integer (nullable = true)
#  |-- _c159: integer (nullable = true)
#  |-- _c160: integer (nullable = true)
#  |-- _c161: integer (nullable = true)
#  |-- _c162: integer (nullable = true)
#  |-- _c163: integer (nullable = true)
#  |-- _c164: integer (nullable = true)
#  |-- _c165: integer (nullable = true)
#  |-- _c166: integer (nullable = true)
#  |-- _c167: integer (nullable = true)
#  |-- _c168: integer (nullable = true)
#  |-- _c169: integer (nullable = true)
#  |-- _c170: integer (nullable = true)
#  |-- _c171: integer (nullable = true)
#  |-- _c172: integer (nullable = true)
#  |-- _c173: integer (nullable = true)
#  |-- _c174: integer (nullable = true)
#  |-- _c175: integer (nullable = true)
#  |-- _c176: integer (nullable = true)
#  |-- _c177: integer (nullable = true)
#  |-- _c178: integer (nullable = true)
#  |-- _c179: integer (nullable = true)
#  |-- _c180: integer (nullable = true)
#  |-- _c181: integer (nullable = true)
#  |-- _c182: integer (nullable = true)
#  |-- _c183: integer (nullable = true)
#  |-- _c184: integer (nullable = true)
#  |-- _c185: integer (nullable = true)
#  |-- _c186: integer (nullable = true)
#  |-- _c187: integer (nullable = true)
#  |-- _c188: integer (nullable = true)
#  |-- _c189: integer (nullable = true)
#  |-- _c190: integer (nullable = true)
#  |-- _c191: integer (nullable = true)
#  |-- _c192: integer (nullable = true)
#  |-- _c193: integer (nullable = true)
#  |-- _c194: integer (nullable = true)
#  |-- _c195: integer (nullable = true)
#  |-- _c196: integer (nullable = true)
#  |-- _c197: integer (nullable = true)
#  |-- _c198: integer (nullable = true)
#  |-- _c199: integer (nullable = true)
#  |-- _c200: integer (nullable = true)
#  |-- _c201: integer (nullable = true)
#  |-- _c202: integer (nullable = true)
#  |-- _c203: integer (nullable = true)
#  |-- _c204: integer (nullable = true)
#  |-- _c205: integer (nullable = true)
#  |-- _c206: integer (nullable = true)
#  |-- _c207: integer (nullable = true)
#  |-- _c208: integer (nullable = true)
#  |-- _c209: integer (nullable = true)
#  |-- _c210: integer (nullable = true)
#  |-- _c211: integer (nullable = true)
#  |-- _c212: integer (nullable = true)
#  |-- _c213: integer (nullable = true)
#  |-- _c214: integer (nullable = true)
#  |-- _c215: integer (nullable = true)
#  |-- _c216: integer (nullable = true)
#  |-- _c217: integer (nullable = true)
#  |-- _c218: integer (nullable = true)
#  |-- _c219: integer (nullable = true)
#  |-- _c220: integer (nullable = true)
#  |-- _c221: integer (nullable = true)
#  |-- _c222: integer (nullable = true)
#  |-- _c223: integer (nullable = true)
#  |-- _c224: integer (nullable = true)
#  |-- _c225: integer (nullable = true)
#  |-- _c226: integer (nullable = true)
#  |-- _c227: integer (nullable = true)
#  |-- _c228: integer (nullable = true)
#  |-- _c229: integer (nullable = true)
#  |-- _c230: integer (nullable = true)
#  |-- _c231: integer (nullable = true)
#  |-- _c232: integer (nullable = true)
#  |-- _c233: integer (nullable = true)
#  |-- _c234: integer (nullable = true)
#  |-- _c235: integer (nullable = true)
#  |-- _c236: integer (nullable = true)
#  |-- _c237: integer (nullable = true)
#  |-- _c238: integer (nullable = true)
#  |-- _c239: integer (nullable = true)
#  |-- _c240: integer (nullable = true)
#  |-- _c241: integer (nullable = true)
#  |-- _c242: integer (nullable = true)
#  |-- _c243: integer (nullable = true)
#  |-- _c244: integer (nullable = true)
#  |-- _c245: integer (nullable = true)
#  |-- _c246: integer (nullable = true)
#  |-- _c247: integer (nullable = true)
#  |-- _c248: integer (nullable = true)
#  |-- _c249: integer (nullable = true)
#  |-- _c250: integer (nullable = true)
#  |-- _c251: integer (nullable = true)
#  |-- _c252: integer (nullable = true)
#  |-- _c253: integer (nullable = true)
#  |-- _c254: integer (nullable = true)
#  |-- _c255: integer (nullable = true)
#  |-- _c256: integer (nullable = true)
#  |-- _c257: integer (nullable = true)
#  |-- _c258: integer (nullable = true)
#  |-- _c259: integer (nullable = true)
#  |-- _c260: integer (nullable = true)
#  |-- _c261: integer (nullable = true)
#  |-- _c262: integer (nullable = true)
#  |-- _c263: integer (nullable = true)
#  |-- _c264: integer (nullable = true)
#  |-- _c265: integer (nullable = true)
#  |-- _c266: integer (nullable = true)
#  |-- _c267: integer (nullable = true)
#  |-- _c268: integer (nullable = true)
#  |-- _c269: integer (nullable = true)
#  |-- _c270: integer (nullable = true)
#  |-- _c271: integer (nullable = true)
#  |-- _c272: integer (nullable = true)
#  |-- _c273: integer (nullable = true)
#  |-- _c274: integer (nullable = true)
#  |-- _c275: integer (nullable = true)
#  |-- _c276: integer (nullable = true)
#  |-- _c277: integer (nullable = true)
#  |-- _c278: integer (nullable = true)
#  |-- _c279: integer (nullable = true)
#  |-- _c280: integer (nullable = true)
#  |-- _c281: integer (nullable = true)
#  |-- _c282: integer (nullable = true)
#  |-- _c283: integer (nullable = true)
#  |-- _c284: integer (nullable = true)
#  |-- _c285: integer (nullable = true)
#  |-- _c286: integer (nullable = true)
#  |-- _c287: integer (nullable = true)
#  |-- _c288: integer (nullable = true)
#  |-- _c289: integer (nullable = true)
#  |-- _c290: integer (nullable = true)
#  |-- _c291: integer (nullable = true)
#  |-- _c292: integer (nullable = true)
#  |-- _c293: integer (nullable = true)
#  |-- _c294: integer (nullable = true)
#  |-- _c295: integer (nullable = true)
#  |-- _c296: integer (nullable = true)
#  |-- _c297: integer (nullable = true)
#  |-- _c298: integer (nullable = true)
#  |-- _c299: integer (nullable = true)
#  |-- _c300: integer (nullable = true)
#  |-- _c301: integer (nullable = true)
#  |-- _c302: integer (nullable = true)
#  |-- _c303: integer (nullable = true)
#  |-- _c304: integer (nullable = true)
#  |-- _c305: integer (nullable = true)
#  |-- _c306: integer (nullable = true)
#  |-- _c307: integer (nullable = true)
#  |-- _c308: integer (nullable = true)
#  |-- _c309: integer (nullable = true)
#  |-- _c310: integer (nullable = true)
#  |-- _c311: integer (nullable = true)
#  |-- _c312: integer (nullable = true)
#  |-- _c313: integer (nullable = true)
#  |-- _c314: integer (nullable = true)
#  |-- _c315: integer (nullable = true)
#  |-- _c316: integer (nullable = true)
#  |-- _c317: integer (nullable = true)
#  |-- _c318: integer (nullable = true)
#  |-- _c319: integer (nullable = true)
#  |-- _c320: integer (nullable = true)
#  |-- _c321: integer (nullable = true)
#  |-- _c322: integer (nullable = true)
#  |-- _c323: integer (nullable = true)
#  |-- _c324: integer (nullable = true)
#  |-- _c325: integer (nullable = true)
#  |-- _c326: integer (nullable = true)
#  |-- _c327: integer (nullable = true)
#  |-- _c328: integer (nullable = true)
#  |-- _c329: integer (nullable = true)
#  |-- _c330: integer (nullable = true)
#  |-- _c331: integer (nullable = true)
#  |-- _c332: integer (nullable = true)
#  |-- _c333: integer (nullable = true)
#  |-- _c334: integer (nullable = true)
#  |-- _c335: integer (nullable = true)
#  |-- _c336: integer (nullable = true)
#  |-- _c337: integer (nullable = true)
#  |-- _c338: integer (nullable = true)
#  |-- _c339: integer (nullable = true)
#  |-- _c340: integer (nullable = true)
#  |-- _c341: integer (nullable = true)
#  |-- _c342: integer (nullable = true)
#  |-- _c343: integer (nullable = true)
#  |-- _c344: integer (nullable = true)
#  |-- _c345: integer (nullable = true)
#  |-- _c346: integer (nullable = true)
#  |-- _c347: integer (nullable = true)
#  |-- _c348: integer (nullable = true)
#  |-- _c349: integer (nullable = true)
#  |-- _c350: integer (nullable = true)
#  |-- _c351: integer (nullable = true)
#  |-- _c352: integer (nullable = true)
#  |-- _c353: integer (nullable = true)
#  |-- _c354: integer (nullable = true)
#  |-- _c355: integer (nullable = true)
#  |-- _c356: integer (nullable = true)
#  |-- _c357: integer (nullable = true)
#  |-- _c358: integer (nullable = true)
#  |-- _c359: integer (nullable = true)
#  |-- _c360: integer (nullable = true)
#  |-- _c361: integer (nullable = true)
#  |-- _c362: integer (nullable = true)
#  |-- _c363: integer (nullable = true)
#  |-- _c364: integer (nullable = true)
#  |-- _c365: integer (nullable = true)
#  |-- _c366: integer (nullable = true)
#  |-- _c367: integer (nullable = true)
#  |-- _c368: integer (nullable = true)
#  |-- _c369: integer (nullable = true)
#  |-- _c370: integer (nullable = true)
#  |-- _c371: integer (nullable = true)
#  |-- _c372: integer (nullable = true)
#  |-- _c373: integer (nullable = true)
#  |-- _c374: integer (nullable = true)
#  |-- _c375: integer (nullable = true)
#  |-- _c376: integer (nullable = true)
#  |-- _c377: integer (nullable = true)
#  |-- _c378: integer (nullable = true)
#  |-- _c379: integer (nullable = true)
#  |-- _c380: integer (nullable = true)
#  |-- _c381: integer (nullable = true)
#  |-- _c382: integer (nullable = true)
#  |-- _c383: integer (nullable = true)
#  |-- _c384: integer (nullable = true)
#  |-- _c385: integer (nullable = true)
#  |-- _c386: integer (nullable = true)
#  |-- _c387: integer (nullable = true)
#  |-- _c388: integer (nullable = true)
#  |-- _c389: integer (nullable = true)
#  |-- _c390: integer (nullable = true)
#  |-- _c391: integer (nullable = true)
#  |-- _c392: integer (nullable = true)
#  |-- _c393: integer (nullable = true)
#  |-- _c394: integer (nullable = true)
#  |-- _c395: integer (nullable = true)
#  |-- _c396: integer (nullable = true)
#  |-- _c397: integer (nullable = true)
#  |-- _c398: integer (nullable = true)
#  |-- _c399: integer (nullable = true)
#  |-- _c400: integer (nullable = true)
#  |-- _c401: integer (nullable = true)
#  |-- _c402: integer (nullable = true)
#  |-- _c403: integer (nullable = true)
#  |-- _c404: integer (nullable = true)
#  |-- _c405: integer (nullable = true)
#  |-- _c406: integer (nullable = true)
#  |-- _c407: integer (nullable = true)
#  |-- _c408: integer (nullable = true)
#  |-- _c409: integer (nullable = true)
#  |-- _c410: integer (nullable = true)
#  |-- _c411: integer (nullable = true)
#  |-- _c412: integer (nullable = true)
#  |-- _c413: integer (nullable = true)
#  |-- _c414: integer (nullable = true)
#  |-- _c415: integer (nullable = true)
#  |-- _c416: integer (nullable = true)
#  |-- _c417: integer (nullable = true)
#  |-- _c418: integer (nullable = true)
#  |-- _c419: integer (nullable = true)
#  |-- _c420: integer (nullable = true)
#  |-- _c421: integer (nullable = true)
#  |-- _c422: integer (nullable = true)
#  |-- _c423: integer (nullable = true)
#  |-- _c424: integer (nullable = true)
#  |-- _c425: integer (nullable = true)
#  |-- _c426: integer (nullable = true)
#  |-- _c427: integer (nullable = true)
#  |-- _c428: integer (nullable = true)
#  |-- _c429: integer (nullable = true)
#  |-- _c430: integer (nullable = true)
#  |-- _c431: integer (nullable = true)
#  |-- _c432: integer (nullable = true)
#  |-- _c433: integer (nullable = true)
#  |-- _c434: integer (nullable = true)
#  |-- _c435: integer (nullable = true)
#  |-- _c436: integer (nullable = true)
#  |-- _c437: integer (nullable = true)
#  |-- _c438: integer (nullable = true)
#  |-- _c439: integer (nullable = true)
#  |-- _c440: integer (nullable = true)
#  |-- _c441: integer (nullable = true)
#  |-- _c442: integer (nullable = true)
#  |-- _c443: integer (nullable = true)
#  |-- _c444: integer (nullable = true)
#  |-- _c445: integer (nullable = true)
#  |-- _c446: integer (nullable = true)
#  |-- _c447: integer (nullable = true)
#  |-- _c448: integer (nullable = true)
#  |-- _c449: integer (nullable = true)
#  |-- _c450: integer (nullable = true)
#  |-- _c451: integer (nullable = true)
#  |-- _c452: integer (nullable = true)
#  |-- _c453: integer (nullable = true)
#  |-- _c454: integer (nullable = true)
#  |-- _c455: integer (nullable = true)
#  |-- _c456: integer (nullable = true)
#  |-- _c457: integer (nullable = true)
#  |-- _c458: integer (nullable = true)
#  |-- _c459: integer (nullable = true)
#  |-- _c460: integer (nullable = true)
#  |-- _c461: integer (nullable = true)
#  |-- _c462: integer (nullable = true)
#  |-- _c463: integer (nullable = true)
#  |-- _c464: integer (nullable = true)
#  |-- _c465: integer (nullable = true)
#  |-- _c466: integer (nullable = true)
#  |-- _c467: integer (nullable = true)
#  |-- _c468: integer (nullable = true)
#  |-- _c469: integer (nullable = true)
#  |-- _c470: integer (nullable = true)
#  |-- _c471: integer (nullable = true)
#  |-- _c472: integer (nullable = true)
#  |-- _c473: integer (nullable = true)
#  |-- _c474: integer (nullable = true)
#  |-- _c475: integer (nullable = true)
#  |-- _c476: integer (nullable = true)
#  |-- _c477: integer (nullable = true)
#  |-- _c478: integer (nullable = true)
#  |-- _c479: integer (nullable = true)
#  |-- _c480: integer (nullable = true)
#  |-- _c481: integer (nullable = true)
#  |-- _c482: integer (nullable = true)
#  |-- _c483: integer (nullable = true)
#  |-- _c484: integer (nullable = true)
#  |-- _c485: integer (nullable = true)
#  |-- _c486: integer (nullable = true)
#  |-- _c487: integer (nullable = true)
#  |-- _c488: integer (nullable = true)
#  |-- _c489: integer (nullable = true)
#  |-- _c490: integer (nullable = true)
#  |-- _c491: integer (nullable = true)
#  |-- _c492: integer (nullable = true)
#  |-- _c493: integer (nullable = true)
#  |-- _c494: integer (nullable = true)
#  |-- _c495: integer (nullable = true)
#  |-- _c496: integer (nullable = true)
#  |-- _c497: integer (nullable = true)
#  |-- _c498: integer (nullable = true)
#  |-- _c499: integer (nullable = true)
#  |-- _c500: integer (nullable = true)
#  |-- _c501: integer (nullable = true)
#  |-- _c502: integer (nullable = true)
#  |-- _c503: integer (nullable = true)
#  |-- _c504: integer (nullable = true)
#  |-- _c505: integer (nullable = true)
#  |-- _c506: integer (nullable = true)
#  |-- _c507: integer (nullable = true)
#  |-- _c508: integer (nullable = true)
#  |-- _c509: integer (nullable = true)
#  |-- _c510: integer (nullable = true)
#  |-- _c511: integer (nullable = true)
#  |-- _c512: integer (nullable = true)
#  |-- _c513: integer (nullable = true)
#  |-- _c514: integer (nullable = true)
#  |-- _c515: integer (nullable = true)
#  |-- _c516: integer (nullable = true)
#  |-- _c517: integer (nullable = true)
#  |-- _c518: integer (nullable = true)
#  |-- _c519: integer (nullable = true)
#  |-- _c520: integer (nullable = true)
#  |-- _c521: integer (nullable = true)
#  |-- _c522: integer (nullable = true)
#  |-- _c523: integer (nullable = true)
#  |-- _c524: integer (nullable = true)
#  |-- _c525: integer (nullable = true)
#  |-- _c526: integer (nullable = true)
#  |-- _c527: integer (nullable = true)
#  |-- _c528: integer (nullable = true)
#  |-- _c529: integer (nullable = true)
#  |-- _c530: integer (nullable = true)
#  |-- _c531: integer (nullable = true)
#  |-- _c532: integer (nullable = true)
#  |-- _c533: integer (nullable = true)
#  |-- _c534: integer (nullable = true)
#  |-- _c535: integer (nullable = true)
#  |-- _c536: integer (nullable = true)
#  |-- _c537: integer (nullable = true)
#  |-- _c538: integer (nullable = true)
#  |-- _c539: integer (nullable = true)
#  |-- _c540: integer (nullable = true)
#  |-- _c541: integer (nullable = true)
#  |-- _c542: integer (nullable = true)
#  |-- _c543: integer (nullable = true)
#  |-- _c544: integer (nullable = true)
#  |-- _c545: integer (nullable = true)
#  |-- _c546: integer (nullable = true)
#  |-- _c547: integer (nullable = true)
#  |-- _c548: integer (nullable = true)
#  |-- _c549: integer (nullable = true)
#  |-- _c550: integer (nullable = true)
#  |-- _c551: integer (nullable = true)
#  |-- _c552: integer (nullable = true)
#  |-- _c553: integer (nullable = true)
#  |-- _c554: integer (nullable = true)
#  |-- _c555: integer (nullable = true)
#  |-- _c556: integer (nullable = true)
#  |-- _c557: integer (nullable = true)
#  |-- _c558: integer (nullable = true)
#  |-- _c559: integer (nullable = true)
#  |-- _c560: integer (nullable = true)
#  |-- _c561: integer (nullable = true)
#  |-- _c562: integer (nullable = true)
#  |-- _c563: integer (nullable = true)
#  |-- _c564: integer (nullable = true)
#  |-- _c565: integer (nullable = true)
#  |-- _c566: integer (nullable = true)
#  |-- _c567: integer (nullable = true)
#  |-- _c568: integer (nullable = true)
#  |-- _c569: integer (nullable = true)
#  |-- _c570: integer (nullable = true)
#  |-- _c571: integer (nullable = true)
#  |-- _c572: integer (nullable = true)
#  |-- _c573: integer (nullable = true)
#  |-- _c574: integer (nullable = true)
#  |-- _c575: integer (nullable = true)
#  |-- _c576: integer (nullable = true)
#  |-- _c577: integer (nullable = true)
#  |-- _c578: integer (nullable = true)
#  |-- _c579: integer (nullable = true)
#  |-- _c580: integer (nullable = true)
#  |-- _c581: integer (nullable = true)
#  |-- _c582: integer (nullable = true)
#  |-- _c583: integer (nullable = true)
#  |-- _c584: integer (nullable = true)
#  |-- _c585: integer (nullable = true)
#  |-- _c586: integer (nullable = true)
#  |-- _c587: integer (nullable = true)
#  |-- _c588: integer (nullable = true)
#  |-- _c589: integer (nullable = true)
#  |-- _c590: integer (nullable = true)
#  |-- _c591: integer (nullable = true)
#  |-- _c592: integer (nullable = true)
#  |-- _c593: integer (nullable = true)
#  |-- _c594: integer (nullable = true)
#  |-- _c595: integer (nullable = true)
#  |-- _c596: integer (nullable = true)
#  |-- _c597: integer (nullable = true)
#  |-- _c598: integer (nullable = true)
#  |-- _c599: integer (nullable = true)
#  |-- _c600: integer (nullable = true)
#  |-- _c601: integer (nullable = true)
#  |-- _c602: integer (nullable = true)
#  |-- _c603: integer (nullable = true)
#  |-- _c604: integer (nullable = true)
#  |-- _c605: integer (nullable = true)
#  |-- _c606: integer (nullable = true)
#  |-- _c607: integer (nullable = true)
#  |-- _c608: integer (nullable = true)
#  |-- _c609: integer (nullable = true)
#  |-- _c610: integer (nullable = true)
#  |-- _c611: integer (nullable = true)
#  |-- _c612: integer (nullable = true)
#  |-- _c613: integer (nullable = true)
#  |-- _c614: integer (nullable = true)
#  |-- _c615: integer (nullable = true)
#  |-- _c616: integer (nullable = true)
#  |-- _c617: integer (nullable = true)
#  |-- _c618: integer (nullable = true)
#  |-- _c619: integer (nullable = true)
#  |-- _c620: integer (nullable = true)
#  |-- _c621: integer (nullable = true)
#  |-- _c622: integer (nullable = true)
#  |-- _c623: integer (nullable = true)
#  |-- _c624: integer (nullable = true)
#  |-- _c625: integer (nullable = true)
#  |-- _c626: integer (nullable = true)
#  |-- _c627: integer (nullable = true)
#  |-- _c628: integer (nullable = true)
#  |-- _c629: integer (nullable = true)
#  |-- _c630: integer (nullable = true)
#  |-- _c631: integer (nullable = true)
#  |-- _c632: integer (nullable = true)
#  |-- _c633: integer (nullable = true)
#  |-- _c634: integer (nullable = true)
#  |-- _c635: integer (nullable = true)
#  |-- _c636: integer (nullable = true)
#  |-- _c637: integer (nullable = true)
#  |-- _c638: integer (nullable = true)
#  |-- _c639: integer (nullable = true)
#  |-- _c640: integer (nullable = true)
#  |-- _c641: integer (nullable = true)
#  |-- _c642: integer (nullable = true)
#  |-- _c643: integer (nullable = true)
#  |-- _c644: integer (nullable = true)
#  |-- _c645: integer (nullable = true)
#  |-- _c646: integer (nullable = true)
#  |-- _c647: integer (nullable = true)
#  |-- _c648: integer (nullable = true)
#  |-- _c649: integer (nullable = true)
#  |-- _c650: integer (nullable = true)
#  |-- _c651: integer (nullable = true)
#  |-- _c652: integer (nullable = true)
#  |-- _c653: integer (nullable = true)
#  |-- _c654: integer (nullable = true)
#  |-- _c655: integer (nullable = true)
#  |-- _c656: integer (nullable = true)
#  |-- _c657: integer (nullable = true)
#  |-- _c658: integer (nullable = true)
#  |-- _c659: integer (nullable = true)
#  |-- _c660: integer (nullable = true)
#  |-- _c661: integer (nullable = true)
#  |-- _c662: integer (nullable = true)
#  |-- _c663: integer (nullable = true)
#  |-- _c664: integer (nullable = true)
#  |-- _c665: integer (nullable = true)
#  |-- _c666: integer (nullable = true)
#  |-- _c667: integer (nullable = true)
#  |-- _c668: integer (nullable = true)
#  |-- _c669: integer (nullable = true)
#  |-- _c670: integer (nullable = true)
#  |-- _c671: integer (nullable = true)
#  |-- _c672: integer (nullable = true)
#  |-- _c673: integer (nullable = true)
#  |-- _c674: integer (nullable = true)
#  |-- _c675: integer (nullable = true)
#  |-- _c676: integer (nullable = true)
#  |-- _c677: integer (nullable = true)
#  |-- _c678: integer (nullable = true)
#  |-- _c679: integer (nullable = true)
#  |-- _c680: integer (nullable = true)
#  |-- _c681: integer (nullable = true)
#  |-- _c682: integer (nullable = true)
#  |-- _c683: integer (nullable = true)
#  |-- _c684: integer (nullable = true)
#  |-- _c685: integer (nullable = true)
#  |-- _c686: integer (nullable = true)
#  |-- _c687: integer (nullable = true)
#  |-- _c688: integer (nullable = true)
#  |-- _c689: integer (nullable = true)
#  |-- _c690: integer (nullable = true)
#  |-- _c691: integer (nullable = true)
#  |-- _c692: integer (nullable = true)
#  |-- _c693: integer (nullable = true)
#  |-- _c694: integer (nullable = true)
#  |-- _c695: integer (nullable = true)
#  |-- _c696: integer (nullable = true)
#  |-- _c697: integer (nullable = true)
#  |-- _c698: integer (nullable = true)
#  |-- _c699: integer (nullable = true)
#  |-- _c700: integer (nullable = true)
#  |-- _c701: integer (nullable = true)
#  |-- _c702: integer (nullable = true)
#  |-- _c703: integer (nullable = true)
#  |-- _c704: integer (nullable = true)
#  |-- _c705: integer (nullable = true)
#  |-- _c706: integer (nullable = true)
#  |-- _c707: integer (nullable = true)
#  |-- _c708: integer (nullable = true)
#  |-- _c709: integer (nullable = true)
#  |-- _c710: integer (nullable = true)
#  |-- _c711: integer (nullable = true)
#  |-- _c712: integer (nullable = true)
#  |-- _c713: integer (nullable = true)
#  |-- _c714: integer (nullable = true)
#  |-- _c715: integer (nullable = true)
#  |-- _c716: integer (nullable = true)
#  |-- _c717: integer (nullable = true)
#  |-- _c718: integer (nullable = true)
#  |-- _c719: integer (nullable = true)
#  |-- _c720: integer (nullable = true)
#  |-- _c721: integer (nullable = true)
#  |-- _c722: integer (nullable = true)
#  |-- _c723: integer (nullable = true)
#  |-- _c724: integer (nullable = true)
#  |-- _c725: integer (nullable = true)
#  |-- _c726: integer (nullable = true)
#  |-- _c727: integer (nullable = true)
#  |-- _c728: integer (nullable = true)
#  |-- _c729: integer (nullable = true)
#  |-- _c730: integer (nullable = true)
#  |-- _c731: integer (nullable = true)
#  |-- _c732: integer (nullable = true)
#  |-- _c733: integer (nullable = true)
#  |-- _c734: integer (nullable = true)
#  |-- _c735: integer (nullable = true)
#  |-- _c736: integer (nullable = true)
#  |-- _c737: integer (nullable = true)
#  |-- _c738: integer (nullable = true)
#  |-- _c739: integer (nullable = true)
#  |-- _c740: integer (nullable = true)
#  |-- _c741: integer (nullable = true)
#  |-- _c742: integer (nullable = true)
#  |-- _c743: integer (nullable = true)
#  |-- _c744: integer (nullable = true)
#  |-- _c745: integer (nullable = true)
#  |-- _c746: integer (nullable = true)
#  |-- _c747: integer (nullable = true)
#  |-- _c748: integer (nullable = true)
#  |-- _c749: integer (nullable = true)
#  |-- _c750: integer (nullable = true)
#  |-- _c751: integer (nullable = true)
#  |-- _c752: integer (nullable = true)
#  |-- _c753: integer (nullable = true)
#  |-- _c754: integer (nullable = true)
#  |-- _c755: integer (nullable = true)
#  |-- _c756: integer (nullable = true)
#  |-- _c757: integer (nullable = true)
#  |-- _c758: integer (nullable = true)
#  |-- _c759: integer (nullable = true)
#  |-- _c760: integer (nullable = true)
#  |-- _c761: integer (nullable = true)
#  |-- _c762: integer (nullable = true)
#  |-- _c763: integer (nullable = true)
#  |-- _c764: integer (nullable = true)
#  |-- _c765: integer (nullable = true)
#  |-- _c766: integer (nullable = true)
#  |-- _c767: integer (nullable = true)
#  |-- _c768: integer (nullable = true)
#  |-- _c769: integer (nullable = true)
#  |-- _c770: integer (nullable = true)
#  |-- _c771: integer (nullable = true)
#  |-- _c772: integer (nullable = true)
#  |-- _c773: integer (nullable = true)
#  |-- _c774: integer (nullable = true)
#  |-- _c775: integer (nullable = true)
#  |-- _c776: integer (nullable = true)
#  |-- _c777: integer (nullable = true)
#  |-- _c778: integer (nullable = true)
#  |-- _c779: integer (nullable = true)
#  |-- _c780: integer (nullable = true)
#  |-- _c781: integer (nullable = true)
#  |-- _c782: integer (nullable = true)
#  |-- _c783: integer (nullable = true)
#  |-- _c784: integer (nullable = true)

# %%
# assemble those features to a vector to consume in Spark
train_assembler = VectorAssembler(
    inputCols=train_mnist.columns[1:785],
    outputCol="features")

# assemble those features to a vector to consume in Spark
test_assembler = VectorAssembler(
    inputCols=test_mnist.columns[1:785],
    outputCol="features")

# %%
# Transform pixel0,pixel1...pixel783 to one column named "features"
train_final_data = train_assembler.transform(train_mnist).select("_c0", "features").withColumnRenamed("_c0","label")

# Transform pixel0,pixel1...pixel783 to one column named "features"
test_final_data = test_assembler.transform(test_mnist).select("_c0", "features").withColumnRenamed("_c0","label")

# %%
train_final_data.show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |    5|(784,[152,153,154...|
# |    0|(784,[127,128,129...|
# |    4|(784,[160,161,162...|
# |    1|(784,[158,159,160...|
# |    9|(784,[208,209,210...|
# |    2|(784,[155,156,157...|
# |    1|(784,[124,125,126...|
# |    3|(784,[151,152,153...|
# |    1|(784,[152,153,154...|
# |    4|(784,[134,135,161...|
# |    3|(784,[123,124,125...|
# |    5|(784,[216,217,218...|
# |    3|(784,[143,144,145...|
# |    6|(784,[72,73,74,99...|
# |    1|(784,[151,152,153...|
# |    7|(784,[211,212,213...|
# |    2|(784,[151,152,153...|
# |    8|(784,[159,160,161...|
# |    6|(784,[100,101,102...|
# |    9|(784,[209,210,211...|
# +-----+--------------------+
# only showing top 20 rows

# %%
MC_evaluator = MulticlassClassificationEvaluator(metricName="accuracy") # redictionCol="prediction",

# %%
start_time = time.time()

# Add parameters of your choice here:
classifier = DecisionTreeClassifier(labelCol='label',featuresCol='features',maxDepth=3,maxBins=4)

fitModel = classifier.fit(train_final_data)

print("--- %s seconds ---" % (time.time() - start_time))
print(" ")

predictions = fitModel.transform(test_final_data)

accuracy = (MC_evaluator.evaluate(predictions))*100
print(" ")
print("Accuracy: ",accuracy)
# Out:
# --- 30.27317190170288 seconds ---
#
#
# Accuracy:  45.81

# %%
fitModel.numClasses
# Out:
# 10
